# %% [markdown]
# ### Pattern Problems

# %% [markdown]
# ---
# Square of side N
# ---
# Input : 3
# Output: ['xxx', 'xxx', 'xxx']
#
# Input 5 :
# Output: ['XXXXX', 'XXXXX', 'XXXXX']

# %%
number = int(input('Enter sides need in square'))

def generate_square(number):
    
    square_pattern = []
    for i in range(number):
        square_pattern.append("x"*number)
        print("x "*number)
    return square_pattern;

pattern = generate_square(number)
print(pattern)
# Out:
# Enter sides need in square 5
# x x x x x
# x x x x x
# x x x x x
# x x x x x
# x x x x x
# ['xxxxx', 'xxxxx', 'xxxxx', 'xxxxx', 'xxxxx']

# %% [markdown]
# ---
# Hollow Square Problem
#
# Input: 3
# Ouptput: ['XXXX', 'X X', 'XXX']
#
# Input: 5
# Output: ['XXXXX', 'X   X', 'X   X', 'X   X', 'XXXXX']
# ---

# %%
hollow_square_sides = int(input('Enter sides need in square'))

def generate_hollow_square(number):
    
    pattern = []
    for i in range(number):
        if(i==0 or i==number-1):
            print("*"*number)
            pattern.append("*"*number)
        else:
            str_pattern = "*"
            str_pattern += " "*(number-2)
            str_pattern += "*"
            pattern.append(str_pattern)
            print(str_pattern)
    return pattern;

hollow_pattern = generate_hollow_square(hollow_square_sides)
print(hollow_pattern)
# Out:
# Enter sides need in square 5
# *****
# *   *
# *   *
# *   *
# *****
# ['*****', '*   *', '*   *', '*   *', '*****']

# %% [markdown]
# ---
# Rectangular Pattern
# ---

# %% [markdown]
# input n=4, m=5
#
# Output : ['xxxxx', 'xxxxx', 'xxxxx', 'xxxxx']
#
# input: n=2, m=2
#
# Output :  ['xx', 'xx']

# %%
def rectangular_pattern(rlen,rbreadth):
    rpattern = []
    for i in range(0,rlen):
        rpattern.append("x"*rbreadth)
        print("x"*rbreadth)
    return rpattern;
    


rect_length = int(input("Enter length "))
rect_breadth = int(input("Enter breadth"))
rpattern = rectangular_pattern(rect_length,rect_breadth)
print(rpattern)
# Out:
# Enter length  4
# Enter breadth 5
# xxxxx
# xxxxx
# xxxxx
# xxxxx
# ['xxxxx', 'xxxxx', 'xxxxx', 'xxxxx']
