# %% [markdown]
# ### Sorting Algorithm

# %% [markdown]
# ---
# 10 Bubble Sort
# ---
#
# Bubble Sort is a simple, comparison-based sorting algorithm that works by repeatedly stepping through a list, comparing adjacent elements, and swapping them if they are in the wrong order. This process repeats until the entire list is completely sorted. It is nicknamed "bubble sort" because larger elements progressively "bubble up" to the end of the collection with each iteration

# %%
def bubble_sort(arr):
    size_list = len(arr);
    for p in range(0,size_list):
        print(f"pass {p}")
        for j in range(size_list-p-1):
            if(arr[j]>arr[j+1]):
                temp = arr[j+1]
                arr[j+1]=arr[j]
                arr[j]= temp

    return arr;
                
                
    
    

lst_numbers = [12,11,80,9.5,30,40,20,75]

print("Sorted list",bubble_sort(lst_numbers))
# Out:
# pass 0
# pass 1
# pass 2
# pass 3
# pass 4
# pass 5
# pass 6
# pass 7
# Sorted list [9.5, 11, 12, 20, 30, 40, 75, 80]

# %% [markdown]
# ---
# 11 Selection Sort
# ---
# Selection Sort is a simple, comparison-based sorting algorithm that works by repeatedly finding the smallest (minimum) element from the unsorted part of a list and moving it to the beginning

# %%
def selection_sort(arr):
    size_list = len(arr);
    for p in range(0,size_list-1):
        print(f"pass {p}")
        min_index = p
        for j in range(p+1,size_list):
            if(arr[j]<arr[min_index]):
                min_index = j
        if(p!=min_index):
            print(f"min {min_index}")
            arr[p],arr[min_index] = arr[min_index],arr[p]

    return arr;
                
listA = [12,11,80,9.5,30,40,20,75]

print("Sorted list",selection_sort(listA))
# Out:
# pass 0
# min 3
# pass 1
# pass 2
# min 3
# pass 3
# min 6
# pass 4
# pass 5
# pass 6
# min 7
# Sorted list [9.5, 11, 12, 20, 30, 40, 75, 80]

# %% [markdown]
# ---
# 12 Insertion Sort
# ---
#
# ITS LIKE SORT CARDS
# Insertion Sort is a simple, comparison-based sorting algorithm that builds the final sorted array one element at a time.
# It works much like the way you sort playing cards in your hands: you take one card from an unsorted pile and insert it into its correct position within your already sorted hand

# %%
def insertion_sort(arr):
    size_list = len(arr);
    for i in range(1,size_list):
        current = arr[i]
        p = i-1
        while p>=0:
            if (arr[p]<current):
                break;
            else:
                arr[p+1] = arr[p]
                p-=1
            arr[p+1] = current
    return arr;
                
listA = [12,11,80,9.5,30,2,40,20,75]

print("Sorted list",insertion_sort(listA))
# Out:
# Sorted list [2, 9.5, 11, 12, 20, 30, 40, 75, 80]
